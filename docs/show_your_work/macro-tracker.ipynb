# %%
from guardrails.validator_base import register_validator, PassResult, FailResult
from guardrails import Validator

@register_validator(name="nested_sums_are_correct", data_type="object")
class NestedSumsAreCorrect(Validator):
    def validate(self, value, metadata = {}):
        parsed_value = value
        if 'ingredient_nutrition_breakdown' not in parsed_value:
            return FailResult("ingredient_nutrition_breakdown was not provided.")

        total_calories = sum([x['calories'] for x in parsed_value['ingredient_nutrition_breakdown']])
        total_fat_grams = sum([x['fat_grams'] for x in parsed_value['ingredient_nutrition_breakdown']])
        total_carbs_grams = sum([x['carbs_grams'] for x in parsed_value['ingredient_nutrition_breakdown']])
        total_protein_grams = sum([x['protein_grams'] for x in parsed_value['ingredient_nutrition_breakdown']])

        failures = []
        fix_value = parsed_value
        if total_calories != parsed_value['total_calories']:
            failures.append(f"Total calories is {parsed_value['total_calories']}, but should be {total_calories}.")
            fix_value['total_calories'] = total_calories
        if total_fat_grams != parsed_value['total_fat_grams']:
            failures.append(f"Total fat grams is {parsed_value['total_fat_grams']}, but should be {total_fat_grams}.")
            fix_value['total_fat_grams'] = total_fat_grams
        if total_carbs_grams != parsed_value['total_carbs_grams']:
            failures.append(f"Total carbs grams is {parsed_value['total_carbs_grams']}, but should be {total_carbs_grams}.")
            fix_value['total_carbs_grams'] = total_carbs_grams
        if total_protein_grams != parsed_value['total_protein_grams']:
            failures.append(f"Total protein grams is {parsed_value['total_protein_grams']}, but should be {total_protein_grams}.")
            fix_value['total_protein_grams'] = total_protein_grams
        if failures:
            return FailResult(error_message=" ".join(failures), fix_value=fix_value)
        return PassResult()

# %%
from pydantic import BaseModel, Field
from guardrails import Guard
from guardrails.validators import ValidLength
from guardrails.utils.telemetry_utils import default_otlp_tracer
import openai

class IngredientNutrition(BaseModel):
    ingredient_name: str = Field()
    quantity: int = Field()
    calories: int = Field()
    protein_grams: int = Field()
    fat_grams: int = Field()
    carbs_grams: int = Field()


class Nutrition(BaseModel):
    total_calories: int = Field()
    total_fat_grams: int = Field()
    total_carbs_grams: int = Field()
    total_protein_grams: int = Field()
    ingredient_nutrition_breakdown: list[IngredientNutrition] = Field()

class MacroWrapper(BaseModel):
    macros: Nutrition = Field(validators=[NestedSumsAreCorrect()])
# guard = Guard.from_pydantic(
#     output_class=Nutrition,
    
#     prompt="3 eggs, 2 tablespoons of beans, 1 tortilla (240 calories), some hot sauce",
# )
    
# guard = Guard.from_pydantic(output_class=MacroWrapper, tracer=default_otlp_tracer("guardrails"))

guard = Guard.from_string(validators=[NestedSumsAreCorrect(), ValidLength(min=1, max=1000)], tracer=default_otlp_tracer("guardrails"))

instructions =  """
    You are a nutrition bot that helps people understand how the calorie and macronutrient breakdown of their food.
    Users will write in the meal they ate as a list of ingredients and quantities. For each ingredient, calculate the
    calories, grams of protein, grams of fat, and grams of carbs, and add those all to a big list. Then, sum up the
    total calories, protein, fat, and carbs for the entire meal.
    """
res = guard(
    llm_api=openai.chat.completions.create,
    # msg_history=[{"role": "nutrition bot", "content": instructions}],
    instructions=instructions,
    prompt="3 eggs, 2 tablespoons of beans, 1 tortilla (240 calories), some hot sauce, 1 tablespoon mexican shredded cheese",
    # prompt="3 marshmallows",
    model="gpt-4",
    max_tokens=1024,
    temperature=0.5,
)

guard = Guard.from_string(validators=[ValidLength(min=1, max=10, on_fail="exception")], tracer=default_otlp_tracer("guardrails"))

instructions =  """
    You are a nutrition bot that helps people understand how the calorie and macronutrient breakdown of their food.
    Users will write in the meal they ate as a list of ingredients and quantities. For each ingredient, calculate the
    calories, grams of protein, grams of fat, and grams of carbs, and add those all to a big list. Then, sum up the
    total calories, protein, fat, and carbs for the entire meal.
    """
res = guard(
    llm_api=openai.chat.completions.create,
    # msg_history=[{"role": "nutrition bot", "content": instructions}],
    instructions=instructions,
    prompt="3 eggs, 2 tablespoons of beans, 1 tortilla (240 calories), some hot sauce, 1 tablespoon mexican shredded cheese",
    # prompt="3 marshmallows",
    model="gpt-4",
    max_tokens=1024,
    temperature=0.5,
)

# res = guard.parse("""
#             {
#   "ingredients": [
#     {
#       "name": "egg",
#       "quantity": 3
#     },
#     {
#       "name": "beans",
#       "quantity": 2,
#       "unit": "tablespoons"
#     },
#     {
#       "name": "tortilla",
#       "quantity": 1,
#       "calories": 240
#     },
#     {
#       "name": "hot sauce",
#       "quantity": 1,
#       "unit": "serving"
#     },
#     {
#       "name": "mexican shredded cheese",
#       "quantity": 1,
#       "unit": "tablespoon"
#     }
#   ]
# }
#             """)

print(res.validated_output)
print(res.raw_llm_output)
# Out:
# Overriding of current TracerProvider is not allowed
# /Users/zaydsimjee/workspace/guardrails/.venv/lib/python3.11/site-packages/guardrails/validatorsattr.py:322: UserWarning: Validator nested_sums_are_correct is not valid for element string.
#   warnings.warn(
# https://otlp-gateway-prod-us-east-0.grafana.net/otlp/v1/traces
# HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Overriding of current TracerProvider is not allowed
# https://otlp-gateway-prod-us-east-0.grafana.net/otlp/v1/traces
# HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[11], line 60
#      52 guard = Guard.from_string(validators=[ValidLength(min=1, max=10, on_fail="exception")], tracer=default_otlp_tracer("guardrails"))
#      54 instructions =  """
#      55     You are a nutrition bot that helps people understand how the calorie and macronutrient breakdown of their food.
#      56     Users will write in the meal they ate as a list of ingredients and quantities. For each ingredient, calculate the
#      57     calories, grams of protein, grams of fat, and grams of carbs, and add those all to a big list. Then, sum up the
#      58     total calories, protein, fat, and carbs for the entire meal.
#      59     """
# ---> 60 res = guard(
#      61     llm_api=openai.chat.completions.create,
#      62     # msg_history=[{"role": "nutrition bot", "content": instructions}],
#      63     instructions=instructions,
#      64     prompt="3 eggs, 2 tablespoons of beans, 1 tortilla (240 calories), some hot sauce, 1 tablespoon mexican shredded cheese",
#      65     # prompt="3 marshmallows",
#      66     model="gpt-4",
#      67     max_tokens=1024,
#      68     temperature=0.5,
#      69 )
#      71 # res = guard.parse("""
#      72 #             {
#      73 #   "ingredients": [
#    (...)
#      99 # }
#     100 #             """)
#     102 print(res.validated_output)
#
# File ~/workspace/guardrails/.venv/lib/python3.11/site-packages/guardrails/guard.py:481, in Guard.__call__(self, llm_api, prompt_params, num_reasks, prompt, instructions, msg_history, metadata, full_schema_reask, *args, **kwargs)
#     466     return self._call_sync(
#     467         llm_api,
#     468         prompt_params=prompt_params,
#    (...)
#     477         **kwargs,
#     478     )
#     480 guard_context = contextvars.Context()
# --> 481 return guard_context.run(
#     482     __call,
#     483     self,
#     484     llm_api,
#     485     prompt_params,
#     486     num_reasks,
#     487     prompt,
#     488     instructions,
#     489     msg_history,
#     490     metadata,
#     491     full_schema_reask,
#     492     *args,
#     493     **kwargs,
#     494 )
#
# File ~/workspace/guardrails/.venv/lib/python3.11/site-packages/guardrails/guard.py:466, in Guard.__call__.<locals>.__call(self, llm_api, prompt_params, num_reasks, prompt, instructions, msg_history, metadata, full_schema_reask, *args, **kwargs)
#     452     return self._call_async(
#     453         llm_api,
#     454         prompt_params=prompt_params,
#    (...)
#     463         **kwargs,
#     464     )
#     465 # Otherwise, call the LLM synchronously
# --> 466 return self._call_sync(
#     467     llm_api,
#     468     prompt_params=prompt_params,
#     469     num_reasks=self.num_reasks,
#     470     prompt=prompt,
#     471     instructions=instructions,
#     472     msg_history=msg_history,
#     473     metadata=metadata,
#     474     full_schema_reask=full_schema_reask,
#     475     call_log=call_log,
#     476     *args,
#     477     **kwargs,
#     478 )
#
# File ~/workspace/guardrails/.venv/lib/python3.11/site-packages/guardrails/guard.py:556, in Guard._call_sync(self, llm_api, prompt_params, num_reasks, prompt, instructions, msg_history, metadata, full_schema_reask, call_log, *args, **kwargs)
#     541 with start_action(action_type="guard_call", prompt_params=prompt_params):
#     542     runner = Runner(
#     543         instructions=instructions_obj,
#     544         prompt=prompt_obj,
#    (...)
#     554         full_schema_reask=full_schema_reask,
#     555     )
# --> 556     call = runner(call_log=call_log, prompt_params=prompt_params)
#     557     return ValidationOutcome[OT].from_guard_history(call)
#
# File ~/workspace/guardrails/.venv/lib/python3.11/site-packages/guardrails/run.py:227, in Runner.__call__(self, call_log, prompt_params)
#     224 except Exception as e:
#     225     # Because Pydantic v1 doesn't respect property setters
#     226     call_log._exception = e
# --> 227     raise e
#     228 return call_log
#
# File ~/workspace/guardrails/.venv/lib/python3.11/site-packages/guardrails/run.py:177, in Runner.__call__(self, call_log, prompt_params)
#     174 index = 0
#     175 for index in range(self.num_reasks + 1):
#     176     # Run a single step.
# --> 177     iteration = self.step(
#     178         index=index,
#     179         api=self.api,
#     180         instructions=instructions,
#     181         prompt=prompt,
#     182         msg_history=msg_history,
#     183         prompt_params=prompt_params,
#     184         prompt_schema=prompt_schema,
#     185         instructions_schema=instructions_schema,
#     186         msg_history_schema=msg_history_schema,
#     187         output_schema=output_schema,
#     188         output=self.output if index == 0 else None,
#     189         call_log=call_log,
#     190     )
#     192     # Loop again?
#     193     if not self.do_loop(index, iteration.reasks):
#
# File ~/workspace/guardrails/.venv/lib/python3.11/site-packages/guardrails/utils/telemetry_utils.py:214, in trace.<locals>.trace_wrapper.<locals>.to_trace_or_not_to_trace(*args, **kwargs)
#     210         except Exception as e:
#     211             trace_span.set_status(
#     212                 status=StatusCode.ERROR, description=str(e)
#     213             )
# --> 214             raise e
#     215 else:
#     216     return fn(*args, **kwargs)
#
# File ~/workspace/guardrails/.venv/lib/python3.11/site-packages/guardrails/utils/telemetry_utils.py:208, in trace.<locals>.trace_wrapper.<locals>.to_trace_or_not_to_trace(*args, **kwargs)
#     205 with _tracer.start_as_current_span(name, trace_context) as trace_span:
#     206     try:
#     207         # TODO: Capture args and kwargs as attributes?
# --> 208         response = fn(*args, **kwargs)
#     209         return response
#     210     except Exception as e:
#
# File ~/workspace/guardrails/.venv/lib/python3.11/site-packages/guardrails/run.py:339, in Runner.step(self, index, api, instructions, prompt, msg_history, prompt_params, prompt_schema, instructions_schema, msg_history_schema, output_schema, call_log, output)
#     337     iteration.outputs.error = error_message
#     338     iteration.outputs.exception = e
# --> 339     raise e
#     340 return iteration
#
# File ~/workspace/guardrails/.venv/lib/python3.11/site-packages/guardrails/run.py:322, in Runner.step(self, index, api, instructions, prompt, msg_history, prompt_params, prompt_schema, instructions_schema, msg_history_schema, output_schema, call_log, output)
#     319     reasks, _ = self.introspect(index, parsed_output, output_schema)
#     320 else:
#     321     # Validate: run output validation.
# --> 322     validated_output = self.validate(
#     323         iteration, index, parsed_output, output_schema
#     324     )
#     325     iteration.outputs.validation_output = validated_output
#     327     # Introspect: inspect validated output for reasks.
#
# File ~/workspace/guardrails/.venv/lib/python3.11/site-packages/guardrails/run.py:608, in Runner.validate(self, iteration, index, parsed_output, output_schema, **kwargs)
#     606 """Validate the output."""
#     607 with start_action(action_type="validate", index=index) as action:
# --> 608     validated_output = output_schema.validate(
#     609         iteration, parsed_output, self.metadata, attempt_number=index, **kwargs
#     610     )
#     612     action.log(
#     613         message_type="info",
#     614         validated_output=reasks_to_dict(validated_output),
#     615     )
#     617     return validated_output
#
# File ~/workspace/guardrails/.venv/lib/python3.11/site-packages/guardrails/schema/string_schema.py:161, in StringSchema.validate(self, iteration, data, metadata, attempt_number, **kwargs)
#     152 dummy_key = "string"
#     153 validation = self.root_datatype.collect_validation(
#     154     key=dummy_key,
#     155     value=data,
#    (...)
#     158     },
#     159 )
# --> 161 validated_response, metadata = validator_service.validate(
#     162     value=data,
#     163     metadata=metadata,
#     164     validator_setup=validation,
#     165     iteration=iteration,
#     166 )
#     168 validated_response = {dummy_key: validated_response}
#     170 if check_refrain_in_dict(validated_response):
#     171     # If the data contains a `Refain` value, we return an empty
#     172     # dictionary.
#
# File ~/workspace/guardrails/.venv/lib/python3.11/site-packages/guardrails/validator_service.py:431, in validate(value, metadata, validator_setup, iteration)
#     429 else:
#     430     validator_service = SequentialValidatorService()
# --> 431 return validator_service.validate(
#     432     value,
#     433     metadata,
#     434     validator_setup,
#     435     iteration,
#     436 )
#
# File ~/workspace/guardrails/.venv/lib/python3.11/site-packages/guardrails/validator_service.py:231, in SequentialValidatorService.validate(self, value, metadata, validator_setup, iteration, path)
#     226     self.validate_dependents(
#     227         value, metadata, validator_setup, iteration, property_path
#     228     )
#     230 # Validate the field
# --> 231 value, metadata = self.run_validators(
#     232     iteration, validator_setup, value, metadata, property_path
#     233 )
#     235 return value, metadata
#
# File ~/workspace/guardrails/.venv/lib/python3.11/site-packages/guardrails/validator_service.py:176, in SequentialValidatorService.run_validators(self, iteration, validator_setup, value, metadata, property_path)
#     174 result = validator_logs.validation_result
#     175 if isinstance(result, FailResult):
# --> 176     value = self.perform_correction(
#     177         [result], value, validator, validator.on_fail_descriptor
#     178     )
#     179 elif isinstance(result, PassResult):
#     180     if (
#     181         validator.override_value_on_pass
#     182         and result.value_override is not result.ValueOverrideSentinel
#     183     ):
#
# File ~/workspace/guardrails/.venv/lib/python3.11/site-packages/guardrails/validator_service.py:90, in ValidatorServiceBase.perform_correction(self, results, value, validator, on_fail_descriptor)
#      85     return FieldReAsk(
#      86         incorrect_value=value,
#      87         fail_results=results,
#      88     )
#      89 if on_fail_descriptor == "exception":
# ---> 90     raise ValidationError(
#      91         "Validation failed for field with errors: "
#      92         + ", ".join([result.error_message for result in results])
#      93     )
#      94 if on_fail_descriptor == "filter":
#      95     return Filter()
#
# ValidationError: Validation failed for field with errors: Value has length greater than 10. Please return a shorter output, that is shorter than 10 characters.

# %%
import rich
rich.print(guard.history.last.tree)
# Out:
# Logs
# └── ╭────────────────────────────────────────────────── Step 0 ───────────────────────────────────────────────────╮
#     │ ╭──────────────────────────────────────────────── Prompt ─────────────────────────────────────────────────╮ │
#     │ │ 3 eggs, 2 tablespoons of beans, 1 tortilla (240 calories), some hot sauce, 1 tablespoon mexican         │ │
#     │ │ shredded cheese                                                                                         │ │
#     │ ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────╯ │
#     │ ╭───────────────────────────────────────────── Instructions ──────────────────────────────────────────────╮ │
#     │ │                                                                                                         │ │
#     │ │     You are a nutrition bot that helps people understand how the calorie and macronutrient breakdown of │ │
#     │ │ their food.                                                                                             │ │
#     │ │     Users will write in the meal they ate as a list of ingredients and quantities. For each ingredient, │ │
#     │ │ calculate the                                                                                           │ │
#     │ │     calories, grams of protein, grams of fat, and grams of carbs, and add those all to a big list.      │ │
#     │ │ Then, sum up the                                                                                        │ │
#     │ │     total calories, protein, fat, and carbs for the entire meal.                                        │ │
#     │ │                                                                                                         │ │
#     │ ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────╯ │
#     │ ╭──────────────────────────────────────────── Message History ────────────────────────────────────────────╮ │
#     │ │ No message history.                                                                                     │ │
#     │ ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────╯ │
#     │ ╭──────────────────────────────────────────── Raw LLM Output ─────────────────────────────────────────────╮ │
#     │ │ Here is the nutritional breakdown of your meal:                                                         │ │
#     │ │                                                                                                         │ │
#     │ │ 1. Eggs - 3 eggs                                                                                        │ │
#     │ │    - Calories: 210 (70 calories per egg)                                                                │ │
#     │ │    - Protein: 18g (6g per egg)                                                                          │ │
#     │ │    - Fat: 15g (5g per egg)                                                                              │ │
#     │ │    - Carbs: 3g (1g per egg)                                                                             │ │
#     │ │                                                                                                         │ │
#     │ │ 2. Beans - 2 tablespoons                                                                                │ │
#     │ │    - Calories: 45 (Approximately 22.5 calories per tablespoon)                                          │ │
#     │ │    - Protein: 3g (Approximately 1.5g per tablespoon)                                                    │ │
#     │ │    - Fat: 0g                                                                                            │ │
#     │ │    - Carbs: 8g (Approximately 4g per tablespoon)                                                        │ │
#     │ │                                                                                                         │ │
#     │ │ 3. Tortilla - 1 tortilla                                                                                │ │
#     │ │    - Calories: 240                                                                                      │ │
#     │ │    - Protein: 6g                                                                                        │ │
#     │ │    - Fat: 6g                                                                                            │ │
#     │ │    - Carbs: 40g                                                                                         │ │
#     │ │                                                                                                         │ │
#     │ │ 4. Hot Sauce - Negligible calories, protein, fat, and carbs                                             │ │
#     │ │                                                                                                         │ │
#     │ │ 5. Mexican Shredded Cheese - 1 tablespoon                                                               │ │
#     │ │    - Calories: 50                                                                                       │ │
#     │ │    - Protein: 3g                                                                                        │ │
#     │ │    - Fat: 4g                                                                                            │ │
#     │ │    - Carbs: 0g                                                                                          │ │
#     │ │                                                                                                         │ │
#     │ │ So, the total nutritional breakdown for your meal is:                                                   │ │
#     │ │                                                                                                         │ │
#     │ │    - Total Calories: 545                                                                                │ │
#     │ │    - Total Protein: 30g                                                                                 │ │
#     │ │    - Total Fat: 25g                                                                                     │ │
#     │ │    - Total Carbs: 51g                                                                                   │ │
#     │ ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────╯ │
#     │ ╭─────────────────────────────────────────── Validated Output ────────────────────────────────────────────╮ │
#     │ │ 'Here is the nutritional breakdown of your meal:\n\n1. Eggs - 3 eggs\n   - Calories: 210 (70 calories   │ │
#     │ │ per egg)\n   - Protein: 18g (6g per egg)\n   - Fat: 15g (5g per egg)\n   - Carbs: 3g (1g per egg)\n     │ │
#     │ │ \n2. Beans - 2 tablespoons\n   - Calories: 45 (Approximately 22.5 calories per tablespoon)\n   -        │ │
#     │ │ Protein: 3g (Approximately 1.5g per tablespoon)\n   - Fat: 0g\n   - Carbs: 8g (Approximately 4g per     │ │
#     │ │ tablespoon)\n   \n3. Tortilla - 1 tortilla\n   - Calories: 240\n   - Protein: 6g\n   - Fat: 6g\n   -    │ │
#     │ │ Carbs: 40g\n   \n4. Hot Sauce - Negligible calories, protein, fat, and carbs\n\n5. Mexican Shredded     │ │
#     │ │ Cheese - 1 tablespoon\n   - Calories: 50 \n   - Protein: 3g\n   - Fat: 4g\n   - Carbs: 0g\n\nSo, the    │ │
#     │ │ total nutritional breakdown for your meal is:\n\n   - Total Calories: 545\n   - Total Protein: 30g\n    │ │
#     │ │ - Total Fat: 25g\n   - Total Carbs: 51g'                                                                │ │
#     │ ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────╯ │
#     ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
